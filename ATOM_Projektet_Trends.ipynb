# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/ATOM-Projektet/blob/main/ATOM_Projektet_Trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analyserne i denne notebook er lavet på basis af besvarelse af følgende [spørgeskema](https://forms.office.com/pages/responsepage.aspx?id=3XNeG3F2PUWdnYqEM-bWfVSXqFYjJwxFpxhZi8WZyF9URU9CUUpSOUdYSlJIRzkxQ08zSEwwSVJFSC4u&route=shorturl)
#
# Der er lagt vægt på at detektere trends.
#
# Analyserne i forhold svarene på undersøgelsens spørgsmål er udført og prioriteret som følger:
# 1. Virksomhedsnavn fjenet ved indlæsning af anonimiseringsmæssige hensyn
#
# 2. Antal medarbejdere i virksomheden. Se analysen af svarene under afnittet  "Antal medarbejderer"
#
# 3. Hvilken branche tilhører virksomheden? Se analysen af svarene under afnittet "Brancherne"
#
#
# 4. Virksomheden hører til. Se analysen af svarene under afnittet "Regioner"
#
# 5. Platform der udvikles til (uafhængig af styresystem): Se analysen af svarene under afnittet "Target Platforme".
#
# 6. I virksomheden anvendes følgende programmeringssprog (angiv de vigtigste): Se analysen af svarene under afnittet "Programmerinssprog".
#
# 7. I tilfælde af at der anvendes Javascript, oplys da hvilket framework der anvendes i virksomheden. Se analysen af svarene under afnittet "Javascript frameworks".
#
# 8. Angiv de vigtigste udviklingsmiljøer der anvendes i virksomheden. Se analysen af svarene under afnittet "Udviklingsmiljøer".
#
# 9. Anvendes Artificial Intelligence i forbindelse med udviklingsmiljøet? Se analysen af svarene under afnittet "Anvendelse af AI i udviklingsmiljøet"
#
# 10. I tilfælde af at der anvendes AI i udviklingsarbejdet, hvilket AI-værktøj anvendes der? Se analysen af svarene under afnittet "AI værktøjer i udviklingsarbejdet".
#
# 11. I tilfælde af at der anvendes AI, angiv hvad det anvendes til ? Se analysen af svarene under afnittet "AI understøttede aktiviteter i udviklingsarbejdet".
#
# 12. Angiv de vigtigste systemudviklingsmetoder der anvendes i virksomheden: Se analysen af svarene under afnittet "Systemudviklingsmetoder".
#
# 13. I hvor høj grad overvejes IT-sikkerheds praktikker ifm. softwareudvikling, i din virksomhed? Se analysen af svarene under afnittet "Applikationssikkerhed".
#
# 14. Gør virksomheden særlige tiltag for at sikre bæredygtighed i forbindelse med softwareudvikling?  Er ikke medtaget i analysen for indeværende.
#
# 15. Praktikantens uddannelse. Er ikke medtaget i analysen for indeværende.
#
# 16. Beskriv kort andre metoder, værktøjer og teknologier, som du synes er vigtige at få med i besvarelsen. Er ikke medtaget i analysen.
#
# 17. Navn (udfyldt af): Er ikke medtaget i analysen.
#
# 18. Må vi kontakte dig på et senere tidspunkt for at få uddybet dine svar? Er ikke medtaget i analysen.

# %% [markdown]
# #Opsætning og datainport

# %%
import pandas as pd
from pathlib import Path

from google.colab import drive

# %%
#Mount your Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Load the data for 50 start ups from the 'Colab Notebooks' on your Google drive
dropList = ['Mail', 'Navn','Virksomhedsnavn','Senest ændret tidspunkt','Navn (udfyldt af)']
fileLocation = "drive/My Drive/Colab Notebooks"
fileName = "Anvendelser af teknologier og metoder i it-virksomheder(1-155).xlsx";
dataset = pd.read_excel(f"{fileLocation}/{fileName}").drop(dropList, axis=1)
dataset
# Out:
#       ID      Starttidspunkt Færdiggørelsestidspunkt  \
# 0      2 2023-09-15 14:45:26     2023-09-15 14:46:54
# 1      3 2023-09-18 06:15:43     2023-09-18 11:31:36
# 2      4 2023-09-18 13:12:12     2023-09-18 13:39:22
# 3      5 2023-09-18 13:39:46     2023-09-18 14:02:34
# 4      6 2023-09-19 12:50:29     2023-09-19 14:10:31
# ..   ...                 ...                     ...
# 150  152 2025-10-21 14:06:16     2025-10-21 15:22:07
# 151  153 2025-10-21 16:07:48     2025-10-21 16:13:41
# 152  154 2025-10-24 10:49:11     2025-10-24 11:01:06
# 153  155 2025-10-24 09:30:21     2025-10-24 11:29:51
# 154  156 2025-10-24 12:05:56     2025-10-24 12:10:55
#
#     Antal medarbejdere i virksomheden  \
# 0              under 10 medarbejdere
# 1                  10-49 medarbejdere
# 2                  10-49 medarbejdere
# 3              under 10 medarbejdere
# 4              under 10 medarbejdere
# ..                                ...
# 150             over 250 medarbejdere
# 151            under 10 medarbejdere
# 152             over 250 medarbejdere
# 153               50-249 medarbejdere
# 154             over 250 medarbejdere
#
#                 Hvilken branche tilhører virksomheden?  \
# 0        General software development;Internet og WWW;
# 1    Internet og WWW;Ad tech;General software devel...
# 2                                            Robotics;
# 3                        General software development;
# 4                                               Games;
# ..                                                 ...
# 150  Financial;General software development;Interne...
# 151            General software development;Konsulent;
# 152                   Ikke en IT udviklingsvirksomhed;
# 153                        Konsulent;offentlig sektor;
# 154                      General software development;
#
#     Virksomheden hører til   \
# 0           Region Sjælland
# 1        Region Hovedstaden
# 2        Region Hovedstaden
# 3           Region Sjælland
# 4           Region Sjælland
# ..                      ...
# 150      Region Midtjylland
# 151         Region Sjælland
# 152      Region Hovedstaden
# 153      Region Hovedstaden
# 154      Region Hovedstaden
#
#     Platform der udvikles til (uafhængig af styresystem)  \
# 0                                                 Web;
# 1                                                 Web;
# 2                                                 Web;
# 3                                          Web;Mobile;
# 4                                          Web;Mobile;
# ..                                                 ...
# 150             Cloud/Server;JN Data også mobil / web;
# 151                                  Web;Cloud/Server;
# 152                   Mobile;Web;Desktop;Cloud/Server;
# 153  Web;Mobile;IOT / Raspberry Pie el. lign. ;Clou...
# 154                                               Web;
#
#     I virksomheden anvendes følgende programmeringssprog (angiv de vigtigste)  \
# 0                                                 PHP;
# 1                                       C#;Javascript;
# 2                                 React - TypeScript ;
# 3                                      PHP;Javascript;
# 4                                       C#;Javascript;
# ..                                                 ...
# 150                                 PowerShell;Python;
# 151                                                C#;
# 152                          C#;Javascript;TypeScript;
# 153                                C#;Javascript;Java;
# 154                                C#;typescript, SQL;
#
#     I tilfælde af at der anvendes Javascript, oplys da hvilket framework der anvendes i virksomheden  \
# 0                                                  NaN
# 1                                          Vue;Svelte;
# 2                                               React;
# 3                                         Typescript ;
# 4                                               React;
# ..                                                 ...
# 150                                                NaN
# 151                                             React;
# 152                                 NextJS;React;Node;
# 153                          Vue;jQuery;React;Angular;
# 154                                           Angular;
#
#     Angiv de vigtigste udviklingsmiljøer der anvendes i virksomheden  ...  \
# 0                                  Visual Studio Code;                ...
# 1                    Visual studio;Visual Studio Code;                ...
# 2                                  Visual Studio Code;                ...
# 3                                  Visual Studio Code;                ...
# 4              Visual studio;Unity;Visual Studio Code;                ...
# ..                                                 ...                ...
# 150  Visual Studio Code;Prompt / SQL server Managem...                ...
# 151                  Visual studio;Visual Studio Code;                ...
# 152           Visual Studio Code;Visual studio;Cursor;                ...
# 153            Visual studio;Visual Studio Code;Xcode;                ...
# 154  Visual studio;Visual Studio Code;SQL Studio Se...                ...
#
#     Mulighed for tilbagerulning af ændringer  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 150                               I høj grad
# 151                               I høj grad
# 152                             I nogen grad
# 153                               I høj grad
# 154                               I høj grad
#
#              Sikkerhedshedkrav til applikationen         \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 150                                         I høj grad
# 151                                         I høj grad
# 152                                         I høj grad
# 153                                         I høj grad
# 154                                         I høj grad
#
#     Standardiserede udviklingsmiljøer Standardiserede testprocedurer  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ..                                ...                            ...
# 150                        I høj grad                     I høj grad
# 151                      I nogen grad                     I høj grad
# 152                      I nogen grad                       Ved ikke
# 153                        I høj grad                     I høj grad
# 154                        I høj grad                     I høj grad
#
#     Beskyttelse af produktionsmiljøet  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 150                        I høj grad
# 151                        I høj grad
# 152                        I høj grad
# 153                        I høj grad
# 154                        I høj grad
#
#              Procedure for håndtering af ændrede applikationskrav         \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 150                                         I høj grad
# 151                                       I nogen grad
# 152                                         I høj grad
# 153                                         I høj grad
# 154                                         I høj grad
#
#     Gør virksomheden særlige tiltag for at sikre bæredygtighed i forbindelse med softwareudvikling?   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 150  Ja (uddyb i andet);JN Data producerer selv str...
# 151                                      i nogen grad;
# 152  Bæredygtighed som i form af nedbringe forbrug ...
# 153  Ja (uddyb i andet);Mikroservices klar til genb...
# 154                      Kun gennem gerel performance;
#
#     Praktikantens uddannelse  \
# 0                Datamatiker
# 1                Datamatiker
# 2               Webudvikling
# 3               Webudvikling
# 4                Datamatiker
# ..                       ...
# 150              Datamatiker
# 151              Datamatiker
# 152              Datamatiker
# 153              Datamatiker
# 154              Datamatiker
#
#     Beskriv kort andre metoder, værktøjer og teknologier, som du synes er vigtige at få med i besvarelsen.   \
# 0                                                  NaN
# 1                                                  NaN
# 2                  De bruger Vercel med GitHub Actions
# 3                                                  NaN
# 4            Plastic SCM unity versionsstyring, trello
# ..                                                 ...
# 150    T-sql \nØnsker : Instance Management (SLA) + AD
# 151                                                NaN
# 152       Azure Devops, MS Graph API, Active Directory
# 153                                                NaN
# 154           Benytter NGAX til framwork strukturering
#
#     Må vi kontakte dig på et senere tidspunkt for at få uddybet dine svar?
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 150                                                 Ja
# 151                                                 Ja
# 152                                                 Ja
# 153                                                 Ja
# 154                                                 Ja
#
# [155 rows x 25 columns]

# %% [markdown]
# #Nogle generelle rutiner i Python

# %%
#Return half first=1 or second=2 half year given a datetime structure
def HalfYear(datetime):
  if datetime.date().month > 6:
    return 2
  return 1

# %%
def GetSetAnalysisDataFrame(sourceDataFrame,inclusionSet, attribute):
  matchedList = []
  finishList = []
  halfYearList = []
  yearList = []
  programmeList = []
  otherList = []
  for idx in sourceDataFrame.index:
    row = sourceDataFrame.loc[idx]
    itemList = str(row[attribute]).split(";")
    for item in itemList:
        if (item != '') & (item != 'nan'):
           finishList.append(row['Finish'])
           halfYearList.append(HalfYear(row['Finish']))
           yearList.append(row['Finish'].date().year)
           programmeList.append(row['Programme'])
           if  (item in inclusionSet):
                matchedList.append(item)
           else:
                matchedList.append("Other")
                otherList.append(item)
  data = {
     "FinishList":finishList,
     "Programme":programmeList,
     "HalfYear":halfYearList,
     "Year":yearList,
     attribute: matchedList
      }

  return pd.DataFrame(data), otherList

# %% [markdown]
# #Pre-processing input data

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset=dataset.rename(columns={"Virksomheden hører til ":"Region",
                                "Praktikantens uddannelse":"Programme",
                                "Antal medarbejdere i virksomheden":"Employees",
                                "Hvilken branche tilhører virksomheden?":"Industry",
                                "Logning af ændringer ":"LoggingChanges",
                                "Mulighed for tilbagerulning af ændringer":"OptionForRollBack",
                                "         Sikkerhedshedkrav til applikationen       ":"AppSecurityRequirements",
                                "Standardiserede udviklingsmiljøer":"StandardizedDevEnv",
                                "Standardiserede testprocedurer":"StandardizedTestProc",
                                "Beskyttelse af produktionsmiljøet":"ProtectionProdEnv",
                                "         Procedure for håndtering af ændrede applikationskrav       ":"ProcedureChangedAppReq",
                                "I virksomheden anvendes følgende programmeringssprog (angiv de vigtigste)":"ProgrammingLanguages",
                                "Starttidspunkt":"Start",
                                "Færdiggørelsestidspunkt":"Finish",
                                "Platform der udvikles til (uafhængig af styresystem)":"TargetPlatforms",
                                "I tilfælde af at der anvendes Javascript, oplys da hvilket framework der anvendes i virksomheden":"JSFrameworks",
                                "Angiv de vigtigste udviklingsmiljøer der anvendes i virksomheden":"DevelopmentEnvs",
                                "I tilfælde af at der anvendes AI i udviklingsarbejdet, hvilket AI-værktøj anvendes der?":"AIDevelopmentTools",
                                "I tilfælde af at der anvendes AI, angiv hvad det anvendes til ?":"AIDevelopmentAppliance",
                                "Angiv de vigtigste systemudviklingsmetoder der anvendes i virksomheden":"SystemDevMethods",
                                "Gør virksomheden særlige tiltag for at sikre bæredygtighed i forbindelse med softwareudvikling? ": "SpecificActionSustainability",
                                "Anvendes Artificial Intelligence i forbindelse med udviklingsmiljøet? (OPTIONAL)":"AIAppliedInDevEnv"}

                       )

dataset['Employees'] = dataset['Employees'].str.replace('over 250 medarbejdere', 'Over 250 medarbejdere')
dataset['Employees'] = dataset['Employees'].str.replace('under 10 medarbejdere', 'Under 10 medarbejdere')
dataset['Employees'] = dataset['Employees'].str.replace('Under 10 medarbejdere', '1. Under 10 medarbejdere')
dataset['Employees'] = dataset['Employees'].str.replace('10-49 medarbejdere', '2. 10-49 medarbejdere')
dataset['Employees'] = dataset['Employees'].str.replace('50-249 medarbejdere', '3. 50-249 medarbejdere')
dataset['Employees'] = dataset['Employees'].str.replace('Over 250 medarbejdere', '4. Over 250 medarbejdere')

dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('typescript', 'TypeScript')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('Typescript', 'TypeScript')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('Deplhi / Pascal', 'Delphi/Pascal')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('powershell','PowerShell')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('React native','React Native')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('TypeScript ','TypeScript')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('sql','SQL')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('Ruby (On Rails) ,HTML, CSS','Ruby on Rails')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('objective c','Objective C')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('vue3','VUE3')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('ruby','Ruby')
dataset['ProgrammingLanguages'] = dataset['ProgrammingLanguages'].str.replace('Visual Basic ','Visual Basic')


#dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('Cloud','Cloud/Server')
#dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('Iot','IOT / Raspberry Pie el. lign.')
#dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('IOT','IOT / Raspberry Pie el. lign.')
dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('IOT / Raspberry Pie el. lign.	','IOT / Raspberry Pie el. lign.')
dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('IOT / Raspberry Pie el. lign.\xa0','IOT / Raspberry Pie el. lign.')
dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('Windows Application','Desktop')
dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('Windows Applikation','Desktop')
dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('Windows applikation','Desktop')
dataset['TargetPlatforms'] = dataset['TargetPlatforms'].str.replace('Azure','Cloud/Server')

dataset['DevelopmentEnvs'] = dataset['DevelopmentEnvs'].str.replace('Visual studio','Visual Studio')
dataset['DevelopmentEnvs'] = dataset['DevelopmentEnvs'].str.replace('rider','Rider')
dataset['DevelopmentEnvs'] = dataset['DevelopmentEnvs'].str.replace('intelliJ','IntelliJ')
dataset['DevelopmentEnvs'] = dataset['DevelopmentEnvs'].str.replace('Intellij','IntelliJ')
dataset['DevelopmentEnvs'] = dataset['DevelopmentEnvs'].str.replace('intellij','IntelliJ')
dataset['DevelopmentEnvs'] = dataset['DevelopmentEnvs'].str.replace('Jetbrains IntelliJ','IntelliJ')


dataset['JSFrameworks'] = dataset['JSFrameworks'].str.replace('React Native til mobile','React Native')
dataset['JSFrameworks'] = dataset['JSFrameworks'].str.replace('ReactNative til app udvikling','React Native')
dataset['JSFrameworks'] = dataset['JSFrameworks'].str.replace('NextJS og NuxtJS','NextJS')
dataset['JSFrameworks'] = dataset['JSFrameworks'].str.replace('Next.js','NextJS')
dataset['JSFrameworks'] = dataset['JSFrameworks'].str.replace('NextJs, springboot','NextJS')

dataset['AIDevelopmentTools'] = dataset['AIDevelopmentTools'].str.replace('Jetbrains IntelliJ','IntelliJ')
dataset['AIDevelopmentTools'] = dataset['AIDevelopmentTools'].str.replace('GitHub Copilot\xa0','GitHub Copilot')



dataset = dataset.query('Programme == "Datamatiker" or Programme == "Webudvikling"')
dataset
# Out:
#       ID               Start              Finish                  Employees  \
# 0      2 2023-09-15 14:45:26 2023-09-15 14:46:54  1. Under 10 medarbejdere
# 1      3 2023-09-18 06:15:43 2023-09-18 11:31:36      2. 10-49 medarbejdere
# 2      4 2023-09-18 13:12:12 2023-09-18 13:39:22      2. 10-49 medarbejdere
# 3      5 2023-09-18 13:39:46 2023-09-18 14:02:34  1. Under 10 medarbejdere
# 4      6 2023-09-19 12:50:29 2023-09-19 14:10:31  1. Under 10 medarbejdere
# ..   ...                 ...                 ...                        ...
# 150  152 2025-10-21 14:06:16 2025-10-21 15:22:07   4. Over 250 medarbejdere
# 151  153 2025-10-21 16:07:48 2025-10-21 16:13:41  1. Under 10 medarbejdere
# 152  154 2025-10-24 10:49:11 2025-10-24 11:01:06   4. Over 250 medarbejdere
# 153  155 2025-10-24 09:30:21 2025-10-24 11:29:51     3. 50-249 medarbejdere
# 154  156 2025-10-24 12:05:56 2025-10-24 12:10:55   4. Over 250 medarbejdere
#
#                                               Industry              Region  \
# 0        General software development;Internet og WWW;     Region Sjælland
# 1    Internet og WWW;Ad tech;General software devel...  Region Hovedstaden
# 2                                            Robotics;  Region Hovedstaden
# 3                        General software development;     Region Sjælland
# 4                                               Games;     Region Sjælland
# ..                                                 ...                 ...
# 150  Financial;General software development;Interne...  Region Midtjylland
# 151            General software development;Konsulent;     Region Sjælland
# 152                   Ikke en IT udviklingsvirksomhed;  Region Hovedstaden
# 153                        Konsulent;offentlig sektor;  Region Hovedstaden
# 154                      General software development;  Region Hovedstaden
#
#                                        TargetPlatforms  \
# 0                                                 Web;
# 1                                                 Web;
# 2                                                 Web;
# 3                                          Web;Mobile;
# 4                                          Web;Mobile;
# ..                                                 ...
# 150             Cloud/Server;JN Data også mobil / web;
# 151                                  Web;Cloud/Server;
# 152                   Mobile;Web;Desktop;Cloud/Server;
# 153  Web;Mobile;IOT / Raspberry Pie el. lign.;Cloud...
# 154                                               Web;
#
#           ProgrammingLanguages               JSFrameworks  \
# 0                         PHP;                        NaN
# 1               C#;Javascript;                Vue;Svelte;
# 2          React - TypeScript;                     React;
# 3              PHP;Javascript;               Typescript ;
# 4               C#;Javascript;                     React;
# ..                         ...                        ...
# 150         PowerShell;Python;                        NaN
# 151                        C#;                     React;
# 152  C#;Javascript;TypeScript;         NextJS;React;Node;
# 153        C#;Javascript;Java;  Vue;jQuery;React;Angular;
# 154        C#;TypeScript, SQL;                   Angular;
#
#                                        DevelopmentEnvs  ... OptionForRollBack  \
# 0                                  Visual Studio Code;  ...               NaN
# 1                    Visual Studio;Visual Studio Code;  ...               NaN
# 2                                  Visual Studio Code;  ...               NaN
# 3                                  Visual Studio Code;  ...               NaN
# 4              Visual Studio;Unity;Visual Studio Code;  ...               NaN
# ..                                                 ...  ...               ...
# 150  Visual Studio Code;Prompt / SQL server Managem...  ...        I høj grad
# 151                  Visual Studio;Visual Studio Code;  ...        I høj grad
# 152           Visual Studio Code;Visual Studio;Cursor;  ...      I nogen grad
# 153            Visual Studio;Visual Studio Code;Xcode;  ...        I høj grad
# 154  Visual Studio;Visual Studio Code;SQL Studio Se...  ...        I høj grad
#
#     AppSecurityRequirements StandardizedDevEnv StandardizedTestProc  \
# 0                       NaN                NaN                  NaN
# 1                       NaN                NaN                  NaN
# 2                       NaN                NaN                  NaN
# 3                       NaN                NaN                  NaN
# 4                       NaN                NaN                  NaN
# ..                      ...                ...                  ...
# 150              I høj grad         I høj grad           I høj grad
# 151              I høj grad       I nogen grad           I høj grad
# 152              I høj grad       I nogen grad             Ved ikke
# 153              I høj grad         I høj grad           I høj grad
# 154              I høj grad         I høj grad           I høj grad
#
#     ProtectionProdEnv ProcedureChangedAppReq  \
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
# ..                ...                    ...
# 150        I høj grad             I høj grad
# 151        I høj grad           I nogen grad
# 152        I høj grad             I høj grad
# 153        I høj grad             I høj grad
# 154        I høj grad             I høj grad
#
#                           SpecificActionSustainability     Programme  \
# 0                                                  NaN   Datamatiker
# 1                                                  NaN   Datamatiker
# 2                                                  NaN  Webudvikling
# 3                                                  NaN  Webudvikling
# 4                                                  NaN   Datamatiker
# ..                                                 ...           ...
# 150  Ja (uddyb i andet);JN Data producerer selv str...   Datamatiker
# 151                                      i nogen grad;   Datamatiker
# 152  Bæredygtighed som i form af nedbringe forbrug ...   Datamatiker
# 153  Ja (uddyb i andet);Mikroservices klar til genb...   Datamatiker
# 154                      Kun gennem gerel performance;   Datamatiker
#
#     Beskriv kort andre metoder, værktøjer og teknologier, som du synes er vigtige at få med i besvarelsen.   \
# 0                                                  NaN
# 1                                                  NaN
# 2                  De bruger Vercel med GitHub Actions
# 3                                                  NaN
# 4            Plastic SCM unity versionsstyring, trello
# ..                                                 ...
# 150    T-sql \nØnsker : Instance Management (SLA) + AD
# 151                                                NaN
# 152       Azure Devops, MS Graph API, Active Directory
# 153                                                NaN
# 154           Benytter NGAX til framwork strukturering
#
#     Må vi kontakte dig på et senere tidspunkt for at få uddybet dine svar?
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 150                                                 Ja
# 151                                                 Ja
# 152                                                 Ja
# 153                                                 Ja
# 154                                                 Ja
#
# [151 rows x 25 columns]

# %% [markdown]
# #Antal medarbejderer

# %% [markdown]
# Tabellen herunder viser besvarelsernes fordeling på uddannelse og virksomhedsstørrelse.

# %%
# @title
pd.crosstab(dataset['Employees'],dataset['Programme'])
# Out:
# Programme                  Datamatiker  Webudvikling
# Employees
# 1. Under 10 medarbejdere            41            12
# 2. 10-49 medarbejdere               24             8
# 3. 50-249 medarbejdere              19             4
# 4. Over 250 medarbejdere            35             8

# %% [markdown]
# #Brancher

# %% [markdown]
# Spm. 3. Hvilken branche tilhører virksomheden?
#
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. AI/Machine learning
# 2. Financial
# 3. Games
# 4. General software development
# 5. Internet og WWW
# 6. Security
# 7. Ikke en IT udviklingsvirksomhed
# 8. Konsulent

# %% [markdown]
# ##Python stuff

# %%
IndustrySet = {"AI/Machine learning","Financial","Games","General software development","Internet og WWW","Security","Ikke en IT udviklingsvirksomhed","Konsulent"}

# %%
def GetIndustryCounts(industry):
  GroupByYear = IndustryDataFrame.query(f"Industry == \"{industry}\"").groupby(['Year'])['Industry'].count()
  return GroupByYear.to_list()

# %%
IndustryDataset = dataset[['Finish','Industry','Programme']]

# %%
IndustryDataFrame,OtherIndustryList=GetSetAnalysisDataFrame(IndustryDataset,IndustrySet,"Industry")

# %%
OtherIndustryList
# Out:
# ['Ad tech',
#  'Robotics',
#  'producerer CAD software til elektrikere',
#  'Vinduer og lign',
#  'Forsyning / drift',
#  'CAD systemer til dokumentation af elektriske installationer',
#  'software til web shops',
#  'Måleudstyr til medicinal industri ',
#  'Pharma tech',
#  'Mobile apps',
#  'CRM - ERP platforme',
#  'konsulent',
#  'Konsulenthus',
#  'itafdeing på RUC',
#  'fartøjer',
#  'kommerciel',
#  'udvikling af mobil applikationer',
#  'IOT - facilitymanagemnet saas',
#  'Medievirksomhed',
#  'Green Energy',
#  'Transport',
#  'Remote access til industri-maskiner',
#  'Manufacturing ',
#  'Udvikler spil til genbrugspladser',
#  'uddannelse',
#  'Startup',
#  'læringsplatform',
#  'NGO',
#  'Drone fabrikation med tilhørende software',
#  'Media',
#  'Forsyningsbranchen',
#  'Hardware',
#  ' udvikling til maritim fritid',
#  'Statslig styrelse',
#  'Leasing',
#  'Repair service broker',
#  'dataanalyse',
#  'legal tech',
#  'NGO',
#  'Forening',
#  'Intern udvikling til DSB',
#  'Event virksomhed',
#  'Mediebranchen',
#  'Software as a Service',
#  'total leverandør',
#  'online apotek',
#  'Stregkoder',
#  'talent-profil',
#  'Gods og passager transport',
#  'Lokal interesse organisation ',
#  'energy sektor ',
#  'Sundhedsplatform ',
#  'meterologisk',
#  'offentlig sektor']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
IndustryDataset
# Out:
#                  Finish                                           Industry  \
# 0   2023-09-15 14:46:54      General software development;Internet og WWW;
# 1   2023-09-18 11:31:36  Internet og WWW;Ad tech;General software devel...
# 2   2023-09-18 13:39:22                                          Robotics;
# 3   2023-09-18 14:02:34                      General software development;
# 4   2023-09-19 14:10:31                                             Games;
# ..                  ...                                                ...
# 150 2025-10-21 15:22:07  Financial;General software development;Interne...
# 151 2025-10-21 16:13:41            General software development;Konsulent;
# 152 2025-10-24 11:01:06                   Ikke en IT udviklingsvirksomhed;
# 153 2025-10-24 11:29:51                        Konsulent;offentlig sektor;
# 154 2025-10-24 12:10:55                      General software development;
#
#         Programme
# 0     Datamatiker
# 1     Datamatiker
# 2    Webudvikling
# 3    Webudvikling
# 4     Datamatiker
# ..            ...
# 150   Datamatiker
# 151   Datamatiker
# 152   Datamatiker
# 153   Datamatiker
# 154   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
IndustryDataFrame
# Out:
#              FinishList    Programme  HalfYear  Year  \
# 0   2023-09-15 14:46:54  Datamatiker         2  2023
# 1   2023-09-15 14:46:54  Datamatiker         2  2023
# 2   2023-09-18 11:31:36  Datamatiker         2  2023
# 3   2023-09-18 11:31:36  Datamatiker         2  2023
# 4   2023-09-18 11:31:36  Datamatiker         2  2023
# ..                  ...          ...       ...   ...
# 228 2025-10-21 16:13:41  Datamatiker         2  2025
# 229 2025-10-24 11:01:06  Datamatiker         2  2025
# 230 2025-10-24 11:29:51  Datamatiker         2  2025
# 231 2025-10-24 11:29:51  Datamatiker         2  2025
# 232 2025-10-24 12:10:55  Datamatiker         2  2025
#
#                             Industry
# 0       General software development
# 1                    Internet og WWW
# 2                    Internet og WWW
# 3                              Other
# 4       General software development
# ..                               ...
# 228                        Konsulent
# 229  Ikke en IT udviklingsvirksomhed
# 230                        Konsulent
# 231                            Other
# 232     General software development
#
# [233 rows x 5 columns]

# %% [markdown]
# ##Analyser

# %%
# @title
{
    IndustryDataFrame['Industry']
    .value_counts()
    .plot(kind='bar',
          title='Brancher hvor Zealands datamatiker og web development studerende er i praktik',
          xlabel='Branche',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
plotdata = pd.DataFrame({
    "Other":GetIndustryCounts("Other"),
    "General software development":GetIndustryCounts("General software development"),
    "Internet og WWW":GetIndustryCounts("Internet og WWW"),
    "Games":GetIndustryCounts("Games"),
    "AI/Machine learning":GetIndustryCounts("AI/Machine learning"),
    "Ikke en IT udviklingsvirksomhed":GetIndustryCounts("Ikke en IT udviklingsvirksomhed"),
    "AI/Machine learning":GetIndustryCounts("AI/Machine learning"),
    "Security":GetIndustryCounts("Security"),
    "Financial":GetIndustryCounts("Financial"),
    "Konsulent":GetIndustryCounts("Konsulent")

    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Brancher hvor Zealands datamatiker og web development studerende er i praktik" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Brancher hvor Zealands datamatiker og web development studerende er i praktik (relativt)");

# %% [markdown]
# #Regioner

# %% [markdown]
# Tabellen herunder viser besvarelsernes fordeling på uddannelse og region.

# %%
# @title
pd.crosstab(dataset['Region'],dataset['Programme'])
# Out:
# Programme           Datamatiker  Webudvikling
# Region
# Region Hovedstaden           73            24
# Region Midtjylland            1             0
# Region Sjælland              41             7
# Region Syddanmark             3             1
# uden for Danmark              1             0

# %% [markdown]
# #Target Platforme

# %% [markdown]
# Spm 5. Platform der udvikles til (uafhængig af styresystem)
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. Multiple choice.
# 2. Mainframe
# 3. Mobile
# 4. Web
# 5. Desktop
# 6. Cloud/Server
# 7. Virtual Reality
# 8. IOT / Raspberry Pie el. lign.

# %% [markdown]
# ##Python stuff

# %%
PlatFormSet = {"Mainframe", "Mobile", "Web", "Desktop", "Cloud/Server", "Virtual Reality", "IOT / Raspberry Pie el. lign."}

# %%
def GetPlatformCounts(targetPlat):
  GroupByYear = TargetPlatformDataFrame.query(f"TargetPlatforms == \"{targetPlat}\"").groupby(['Year'])['TargetPlatforms'].count()
  return GroupByYear.to_list()

# %%
TargetPlatDataset = dataset[['Finish','TargetPlatforms','Programme']]

# %%
TargetPlatformDataFrame,OtherTargetPlatformList=GetSetAnalysisDataFrame(TargetPlatDataset,PlatFormSet,"TargetPlatforms")

# %%
OtherTargetPlatformList
# Out:
# ['Iot',
#  'både',
#  'IOT',
#  'hosting',
#  'Alt ovenstående',
#  'support',
#  'Cloud',
#  'Linux',
#  'BI',
#  'Afhænger af kundekrav',
#  'Microsoft dynmacis',
#  'Udvikling til MS 365',
#  'ikke it virksomhed',
#  'hele virksomheden benytter server/mobile',
#  'ikke IT',
#  'JN Data også mobil / web']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
TargetPlatDataset
# Out:
#                  Finish                                    TargetPlatforms  \
# 0   2023-09-15 14:46:54                                               Web;
# 1   2023-09-18 11:31:36                                               Web;
# 2   2023-09-18 13:39:22                                               Web;
# 3   2023-09-18 14:02:34                                        Web;Mobile;
# 4   2023-09-19 14:10:31                                        Web;Mobile;
# ..                  ...                                                ...
# 150 2025-10-21 15:22:07             Cloud/Server;JN Data også mobil / web;
# 151 2025-10-21 16:13:41                                  Web;Cloud/Server;
# 152 2025-10-24 11:01:06                   Mobile;Web;Desktop;Cloud/Server;
# 153 2025-10-24 11:29:51  Web;Mobile;IOT / Raspberry Pie el. lign.;Cloud...
# 154 2025-10-24 12:10:55                                               Web;
#
#         Programme
# 0     Datamatiker
# 1     Datamatiker
# 2    Webudvikling
# 3    Webudvikling
# 4     Datamatiker
# ..            ...
# 150   Datamatiker
# 151   Datamatiker
# 152   Datamatiker
# 153   Datamatiker
# 154   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
TargetPlatformDataFrame
# Out:
#              FinishList     Programme  HalfYear  Year  \
# 0   2023-09-15 14:46:54   Datamatiker         2  2023
# 1   2023-09-18 11:31:36   Datamatiker         2  2023
# 2   2023-09-18 13:39:22  Webudvikling         2  2023
# 3   2023-09-18 14:02:34  Webudvikling         2  2023
# 4   2023-09-18 14:02:34  Webudvikling         2  2023
# ..                  ...           ...       ...   ...
# 283 2025-10-24 11:29:51   Datamatiker         2  2025
# 284 2025-10-24 11:29:51   Datamatiker         2  2025
# 285 2025-10-24 11:29:51   Datamatiker         2  2025
# 286 2025-10-24 11:29:51   Datamatiker         2  2025
# 287 2025-10-24 12:10:55   Datamatiker         2  2025
#
#                    TargetPlatforms
# 0                              Web
# 1                              Web
# 2                              Web
# 3                              Web
# 4                           Mobile
# ..                             ...
# 283                         Mobile
# 284  IOT / Raspberry Pie el. lign.
# 285                   Cloud/Server
# 286                        Desktop
# 287                            Web
#
# [288 rows x 5 columns]

# %% [markdown]
# ##Analyser

# %%
# @title
{
    TargetPlatformDataFrame['TargetPlatforms']
    .value_counts()
    .plot(kind='bar',
          title='Platforme der udvikles til i virksomheden',
          xlabel='Platform',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
plotdata = pd.DataFrame({
    "Web":GetPlatformCounts("Web"),
    "Mobile":GetPlatformCounts("Mobile"),
    "Desktop":GetPlatformCounts("Desktop"),
    "Cloud/Server":GetPlatformCounts("Cloud/Server")
    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Mest udbredte target platform" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Mest udbredte target platform (relativt)");

# %% [markdown]
# #Programmeringssprog

# %% [markdown]
# Spm. 6.I virksomheden anvendes følgende programmeringssprog (angiv de vigtigste)
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. C/C++
# 2. C#
# 3. Dart
# 4. Go
# 5. Java
# 6. Javascript
# 7. Kotlin
# 8. PHP
# 9. Python
# 10. Swift

# %% [markdown]
# ##Python stuff

# %%
LangSet = {"C/C++", "C#", "Dart", "Go", "Java", "Javascript", "Kotlin", "PHP", "Python", "Swift","Delphi/Pascal","SQL","TypeScript","PowerShell","Ruby on Rails","Rust","React Native","Objective C","React", "VUE3","Ruby","Visual Basic","PERL", "COBOLT"}

# %%
ProgLanDataset = dataset[['Finish','ProgrammingLanguages','Programme']]

# %%
def GetLanguageCounts(progLan):
  GroupByYear = ProgLanDataFrame.query(f"ProgrammingLanguages == \"{progLan}\"").groupby(['Year'])['ProgrammingLanguages'].count()
  return GroupByYear.to_list()

# %%
ProgLanDataFrame,OtherProgLanList=GetSetAnalysisDataFrame(ProgLanDataset,LangSet,"ProgrammingLanguages")

# %%
OtherProgLanList
# Out:
# ['React - TypeScript',
#  'flutter',
#  'Microsoft stack',
#  'Liquid code',
#  ' Generelt CSS, Javascript og HTML',
#  'TypeScript, Bash, Cypher query',
#  'DAX - Query Language',
#  'SQL, dax, mdx, R, Scala, spark, html, graphql',
#  'html, css',
#  'MAUI',
#  'Html',
#  'ASP.NET',
#  'HTML/CSS',
#  'Flutter, TypeScript',
#  'html, css',
#  'html - ikke it virksomhed',
#  'anden del benytter javascript',
#  'frontend, html',
#  'yaml',
#  'TypeScript, SQL']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
ProgLanDataset
# Out:
#                  Finish       ProgrammingLanguages     Programme
# 0   2023-09-15 14:46:54                       PHP;   Datamatiker
# 1   2023-09-18 11:31:36             C#;Javascript;   Datamatiker
# 2   2023-09-18 13:39:22        React - TypeScript;  Webudvikling
# 3   2023-09-18 14:02:34            PHP;Javascript;  Webudvikling
# 4   2023-09-19 14:10:31             C#;Javascript;   Datamatiker
# ..                  ...                        ...           ...
# 150 2025-10-21 15:22:07         PowerShell;Python;   Datamatiker
# 151 2025-10-21 16:13:41                        C#;   Datamatiker
# 152 2025-10-24 11:01:06  C#;Javascript;TypeScript;   Datamatiker
# 153 2025-10-24 11:29:51        C#;Javascript;Java;   Datamatiker
# 154 2025-10-24 12:10:55        C#;TypeScript, SQL;   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
ProgLanDataFrame
# Out:
#              FinishList     Programme  HalfYear  Year ProgrammingLanguages
# 0   2023-09-15 14:46:54   Datamatiker         2  2023                  PHP
# 1   2023-09-18 11:31:36   Datamatiker         2  2023                   C#
# 2   2023-09-18 11:31:36   Datamatiker         2  2023           Javascript
# 3   2023-09-18 13:39:22  Webudvikling         2  2023                Other
# 4   2023-09-18 14:02:34  Webudvikling         2  2023                  PHP
# ..                  ...           ...       ...   ...                  ...
# 346 2025-10-24 11:29:51   Datamatiker         2  2025                   C#
# 347 2025-10-24 11:29:51   Datamatiker         2  2025           Javascript
# 348 2025-10-24 11:29:51   Datamatiker         2  2025                 Java
# 349 2025-10-24 12:10:55   Datamatiker         2  2025                   C#
# 350 2025-10-24 12:10:55   Datamatiker         2  2025                Other
#
# [351 rows x 5 columns]

# %% [markdown]
# ##Analyser

# %%
# @title
{
    ProgLanDataFrame['ProgrammingLanguages']
    .value_counts()
    .plot(kind='bar',
          title='Programmeringssporg anvendt i virksomheden',
          xlabel='Programmeringssporg',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
GroupByHalfYear = ProgLanDataFrame.groupby(['Year', 'HalfYear','Programme'])['ProgrammingLanguages'].count()
GroupByHalfYear
# Out:
# Year  HalfYear  Programme
# 2023  2         Datamatiker      59
#                 Webudvikling     17
# 2024  1         Datamatiker      17
#                 Webudvikling      6
#       2         Datamatiker      79
#                 Webudvikling     42
# 2025  1         Datamatiker      18
#       2         Datamatiker     101
#                 Webudvikling     12
# Name: ProgrammingLanguages, dtype: int64

# %%
# @title
GroupByYear = ProgLanDataFrame.query('ProgrammingLanguages == "Swift"').groupby(['Year'])['ProgrammingLanguages'].count()
GroupByYear
# Out:
# Year
# 2023    2
# 2024    4
# Name: ProgrammingLanguages, dtype: int64

# %%
# @title
plotdata = pd.DataFrame({
    "Javascript":GetLanguageCounts("Javascript"),
    "C#":GetLanguageCounts("C#"),
    "Python":GetLanguageCounts("Python"),
    "PHP":GetLanguageCounts("PHP"),
    "Java":GetLanguageCounts("Java"),
    "TypeScript":GetLanguageCounts("TypeScript")
    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Mest udbredte programmeringssprog" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Mest udbredte programmeringssprog (relativt)");

# %% [markdown]
# #Javascript frameworks

# %% [markdown]
# Spm: 7. I tilfælde af at der anvendes Javascript, oplys da hvilket framework der anvendes i virksomheden.
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. Alpine
# 2. Angular
# 3. Backbone
# 4. Ember
# 5. React
# 6. Svelte
# 7. Vue
# 8. NextJS
# 9. jQuery
# 10. No Javascript framework

# %% [markdown]
# ##Python stuff

# %%
JSFrameSet = {"Alpine", "Angular", "Backbone", "Ember", "React", "Svelte", "Vue", "NextJS", "jQuery", "No Javascript framework", "React Native"}

# %%
JSFramewDataset = dataset[['Finish','JSFrameworks','Programme']]

# %%
def GetJSFrameworkCounts(jsFramew):
  GroupByYear = JSFramewDataFrame.query(f"JSFrameworks == \"{jsFramew}\"").groupby(['Year'])['JSFrameworks'].count()
  return GroupByYear.to_list()

# %%
JSFramewDataFrame,OtherJSFramewList=GetSetAnalysisDataFrame(JSFramewDataset,JSFrameSet,"JSFrameworks")

# %%
OtherJSFramewList
# Out:
# ['Typescript ',
#  'PowerApps',
#  'DevExtreme',
#  'Tailwind',
#  'Javascript. devextreme, "cemfusion"',
#  'CoffeeScript',
#  'Vite, Bootstrap, Axios, TypeScript',
#  'FastAPI',
#  'tailwind',
#  ' bootstrap',
#  'typescript',
#  'quasar',
#  'NodeJS',
#  'google apps scrips',
#  'Blazor',
#  'NodeJS, Superbase',
#  'pure javascript ',
#  'Vanilla',
#  'decanter, numpy, pandas',
#  'Mithrill',
#  'Typescript',
#  'Node']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
JSFramewDataset
# Out:
#                  Finish               JSFrameworks     Programme
# 0   2023-09-15 14:46:54                        NaN   Datamatiker
# 1   2023-09-18 11:31:36                Vue;Svelte;   Datamatiker
# 2   2023-09-18 13:39:22                     React;  Webudvikling
# 3   2023-09-18 14:02:34               Typescript ;  Webudvikling
# 4   2023-09-19 14:10:31                     React;   Datamatiker
# ..                  ...                        ...           ...
# 150 2025-10-21 15:22:07                        NaN   Datamatiker
# 151 2025-10-21 16:13:41                     React;   Datamatiker
# 152 2025-10-24 11:01:06         NextJS;React;Node;   Datamatiker
# 153 2025-10-24 11:29:51  Vue;jQuery;React;Angular;   Datamatiker
# 154 2025-10-24 12:10:55                   Angular;   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyser

# %%
# @title
{
    JSFramewDataFrame['JSFrameworks']
    .value_counts()
    .plot(kind='bar',
          title='Javascript frameworks anvendt i virksomheden',
          xlabel='Frameworkr',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
plotdata = pd.DataFrame({
    "React":GetJSFrameworkCounts("React"),
    "Vue":GetJSFrameworkCounts("Vue"),
    "Angular":GetJSFrameworkCounts("Angular"),
    #"NextJS":GetLanguageCounts("NextJS")

    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Mest udbredte javascript frameworks" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Mest udbredte javascript frameworks (relativt)");

# %% [markdown]
# #Udviklingsmiljøer

# %% [markdown]
# Spm. 7. Angiv de vigtigste udviklingsmiljøer der anvendes i virksomheden
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. Eclipse
# 2. NetBeans
# 3. Oracle JDeveloper
# 4. PhpStorm
# 5. PyCharm
# 6. Selenium IDE
# 7. Visual studio
# 8. Visual Studio Code
# 9. WebStorm
# 10. Xcode
# 11. Unity
# 12. Android Studio

# %% [markdown]
# ##Python stuff

# %%
DevEnvSet = {"Eclipse",
             "NetBeans",
             "Oracle JDeveloper",
             "PhpStorm",
             "PyCharm",
             "Selenium IDE",
             "Visual Studio",
             "Visual Studio Code",
             "WebStorm",
             "Xcode",
             "Unity",
             "Android Studio",
             "RAD Studio",
             "Rider",
             "IntelliJ"}

# %%
DevelopmentEnvDataset = dataset[['Finish','DevelopmentEnvs','Programme']]

# %%
def GetDevelopmentEnvCounts(devEnv):
  GroupByYear = DevelopmentEnvDataFrame.query(f"DevelopmentEnvs == \"{devEnv}\"").groupby(['Year'])['DevelopmentEnvs'].count()
  return GroupByYear.to_list()

# %%
DevelopmentEnvDataFrame,OtherDevelopmentEnvList=GetSetAnalysisDataFrame(DevelopmentEnvDataset,DevEnvSet,"DevelopmentEnvs")

# %%
OtherDevelopmentEnvList
# Out:
# ['Unity, Android studio',
#  'Putty',
#  'service scripts',
#  'DevOps',
#  'terminalen',
#  'editor',
#  'linqpad',
#  'Sublime',
#  'Databrics',
#  'DataBricks',
#  'vim',
#  'Ingen udviklingsmiljø',
#  'WordPress WPCodebox2',
#  'google apps script',
#  'wordpress',
#  'Cloudbaseret - N8N',
#  'Curosr',
#  'Neovim',
#  'Raider',
#  'Prompt / SQL server Management',
#  'Cursor',
#  'SQL Studio Server Management']

# %% [markdown]
# ##Basis datasæt

# %%
# @title

DevelopmentEnvDataset
# Out:
#                  Finish                                    DevelopmentEnvs  \
# 0   2023-09-15 14:46:54                                Visual Studio Code;
# 1   2023-09-18 11:31:36                  Visual Studio;Visual Studio Code;
# 2   2023-09-18 13:39:22                                Visual Studio Code;
# 3   2023-09-18 14:02:34                                Visual Studio Code;
# 4   2023-09-19 14:10:31            Visual Studio;Unity;Visual Studio Code;
# ..                  ...                                                ...
# 150 2025-10-21 15:22:07  Visual Studio Code;Prompt / SQL server Managem...
# 151 2025-10-21 16:13:41                  Visual Studio;Visual Studio Code;
# 152 2025-10-24 11:01:06           Visual Studio Code;Visual Studio;Cursor;
# 153 2025-10-24 11:29:51            Visual Studio;Visual Studio Code;Xcode;
# 154 2025-10-24 12:10:55  Visual Studio;Visual Studio Code;SQL Studio Se...
#
#         Programme
# 0     Datamatiker
# 1     Datamatiker
# 2    Webudvikling
# 3    Webudvikling
# 4     Datamatiker
# ..            ...
# 150   Datamatiker
# 151   Datamatiker
# 152   Datamatiker
# 153   Datamatiker
# 154   Datamatiker
#
# [151 rows x 3 columns]

# %%
# @title
DevelopmentEnvDataFrame
# Out:
#              FinishList     Programme  HalfYear  Year     DevelopmentEnvs
# 0   2023-09-15 14:46:54   Datamatiker         2  2023  Visual Studio Code
# 1   2023-09-18 11:31:36   Datamatiker         2  2023       Visual Studio
# 2   2023-09-18 11:31:36   Datamatiker         2  2023  Visual Studio Code
# 3   2023-09-18 13:39:22  Webudvikling         2  2023  Visual Studio Code
# 4   2023-09-18 14:02:34  Webudvikling         2  2023  Visual Studio Code
# ..                  ...           ...       ...   ...                 ...
# 240 2025-10-24 11:29:51   Datamatiker         2  2025  Visual Studio Code
# 241 2025-10-24 11:29:51   Datamatiker         2  2025               Xcode
# 242 2025-10-24 12:10:55   Datamatiker         2  2025       Visual Studio
# 243 2025-10-24 12:10:55   Datamatiker         2  2025  Visual Studio Code
# 244 2025-10-24 12:10:55   Datamatiker         2  2025               Other
#
# [245 rows x 5 columns]

# %%
# @title
{
    DevelopmentEnvDataFrame['DevelopmentEnvs']
    .value_counts()
    .plot(kind='bar',
          title='Udviklingsomgivelser anvendt i virksomheden',
          xlabel='Udviklingsmiljø',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
plotdata = pd.DataFrame({
    "Visual Studio Code":GetDevelopmentEnvCounts("Visual Studio Code"),
    "Visual Studio":GetDevelopmentEnvCounts("Visual Studio")
    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Mest udbredte udviklingsmiljøer" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Mest udbredte udviklingsmiljøer (relativt)");

# %% [markdown]
# #Anvendelse af AI i udviklingsmiljøet

# %% [markdown]
# Spm. 9: Anvendes Artificial Intelligence i forbindelse med udviklingsmiljøet?
#
# Respondenten kunne vælge et  af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. Ja
# 2. Nej

# %% [markdown]
# ##Python stuff

# %%
AIAppliedInDevEnvSet = {
             "Ja",
             "Nej"}

# %%
AIAppliedInDevEnvDataset = dataset[['Finish','AIAppliedInDevEnv','Programme']]

# %%
AIAppliedInDevEnvDataFrame,OtherAIAppliedInDevEnvList=GetSetAnalysisDataFrame(AIAppliedInDevEnvDataset,AIAppliedInDevEnvSet,"AIAppliedInDevEnv")

# %%
def GetAIAppliedInDevEnCounts(applied):
  GroupByYear = AIAppliedInDevEnvDataFrame.query(f"AIAppliedInDevEnv == \"{applied}\"").groupby(['Year'])['AIAppliedInDevEnv'].count()
  return GroupByYear.to_list()

# %%
OtherAIAppliedInDevEnvList
# Out:
# ['praktikanten introducerer det.', 'Valgfrit', 'micro gen - forslag']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
AIAppliedInDevEnvDataset
# Out:
#                  Finish AIAppliedInDevEnv     Programme
# 0   2023-09-15 14:46:54               Nej   Datamatiker
# 1   2023-09-18 11:31:36               Nej   Datamatiker
# 2   2023-09-18 13:39:22               Nej  Webudvikling
# 3   2023-09-18 14:02:34               Nej  Webudvikling
# 4   2023-09-19 14:10:31               Nej   Datamatiker
# ..                  ...               ...           ...
# 150 2025-10-21 15:22:07                Ja   Datamatiker
# 151 2025-10-21 16:13:41                Ja   Datamatiker
# 152 2025-10-24 11:01:06                Ja   Datamatiker
# 153 2025-10-24 11:29:51                Ja   Datamatiker
# 154 2025-10-24 12:10:55                Ja   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
AIAppliedInDevEnvDataFrame
# Out:
#              FinishList     Programme  HalfYear  Year AIAppliedInDevEnv
# 0   2023-09-15 14:46:54   Datamatiker         2  2023               Nej
# 1   2023-09-18 11:31:36   Datamatiker         2  2023               Nej
# 2   2023-09-18 13:39:22  Webudvikling         2  2023               Nej
# 3   2023-09-18 14:02:34  Webudvikling         2  2023               Nej
# 4   2023-09-19 14:10:31   Datamatiker         2  2023               Nej
# ..                  ...           ...       ...   ...               ...
# 134 2025-10-21 15:22:07   Datamatiker         2  2025                Ja
# 135 2025-10-21 16:13:41   Datamatiker         2  2025                Ja
# 136 2025-10-24 11:01:06   Datamatiker         2  2025                Ja
# 137 2025-10-24 11:29:51   Datamatiker         2  2025                Ja
# 138 2025-10-24 12:10:55   Datamatiker         2  2025                Ja
#
# [139 rows x 5 columns]

# %% [markdown]
# ##Analyser

# %%
# @title
{
    AIAppliedInDevEnvDataFrame['AIAppliedInDevEnv']
    .value_counts()
    .plot(kind='bar',
          title='Anvendes AI i udviklingsomgivelserne i virksomheden?',
          xlabel='Svar',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
plotdata = pd.DataFrame({
    "Ja":GetAIAppliedInDevEnCounts("Ja"),
    "Nej":GetAIAppliedInDevEnCounts("Nej")
    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Anvendes AI i udviklingsomgivelserne i virksomheden?" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Anvendes AI i udviklingsomgivelserne i virksomheden? (relativt)");

# %% [markdown]
# #AI værktøjer i udviklingsarbejdet

# %% [markdown]
# Spm: 10. I tilfælde af at der anvendes AI i udviklingsarbejdet, hvilket AI-værktøj anvendes der?
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. OpenAI (ChatGPT)
# 2. GitHub Copilot
# 3. Bard
# 4. OpenAI Codex
# 6. Amazon CodeWhisper
# 7. SourceGraph

# %% [markdown]
# ##Python stuff

# %%
AIDevToolsSet = {"OpenAI (ChatGPT)",
                 "GitHub Copilot",
                 "Bard",
                 "OpenAI Codex",
                 "Amazon CodeWhisper",
                 "SourceGraph"
                 }

# %%
AIDevelopmentToolsDataset = dataset[['Finish','AIDevelopmentTools','Programme']]

# %%
AIDevelopmentToolsDataFrame,OtherAIDevelopmentToolsList=GetSetAnalysisDataFrame(AIDevelopmentToolsDataset,AIDevToolsSet,"AIDevelopmentTools")

# %%
def GetAIDevelopmentToolsCounts(aiDevTool):
  GroupByYear = AIDevelopmentToolsDataFrame.query(f"AIDevelopmentTools == \"{aiDevTool}\"").groupby(['Year'])['AIDevelopmentTools'].count()
  return GroupByYear.to_list()

# %%
OtherAIDevelopmentToolsList
# Out:
# ['har deres egen chatgpt ',
#  'Phind https://www.phind.com/',
#  'jupiter notebooks',
#  'Ai Assistant',
#  'Big data',
#  'Copilot',
#  'Claude',
#  'Amazon Q',
#  'copilot',
#  'phind',
#  'deeplearning AI',
#  'cursorAI',
#  'perplexity',
#  'Claude',
#  'Grok',
#  'Co-pilot, Claude, Gemini',
#  'Co-pilot, Claude',
#  'Copoilot, Claude',
#  'google script, google Gemini',
#  'Co-pilot',
#  'Claude, Gemini, Grok',
#  'Cursor ai',
#  'Microsoft Copilot',
#  'Solita AI, cursor',
#  'Claude',
#  'itellij AI',
#  'Desuden en lokal LLM',
#  'Cline',
#  'Claude',
#  'lokal OpenAI',
#  'lokal KMD ChatGPT + inddirekte gennem intellisence']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
AIDevelopmentToolsDataset
# Out:
#                  Finish                                 AIDevelopmentTools  \
# 0   2023-09-15 14:46:54                                                NaN
# 1   2023-09-18 11:31:36                                                NaN
# 2   2023-09-18 13:39:22                                                NaN
# 3   2023-09-18 14:02:34                                                NaN
# 4   2023-09-19 14:10:31                                                NaN
# ..                  ...                                                ...
# 150 2025-10-21 15:22:07               GitHub Copilot;Desuden en lokal LLM;
# 151 2025-10-21 16:13:41                            Cline;OpenAI (ChatGPT);
# 152 2025-10-24 11:01:06            OpenAI (ChatGPT);GitHub Copilot;Claude;
# 153 2025-10-24 11:29:51                       GitHub Copilot;lokal OpenAI;
# 154 2025-10-24 12:10:55  lokal KMD ChatGPT + inddirekte gennem intellis...
#
#         Programme
# 0     Datamatiker
# 1     Datamatiker
# 2    Webudvikling
# 3    Webudvikling
# 4     Datamatiker
# ..            ...
# 150   Datamatiker
# 151   Datamatiker
# 152   Datamatiker
# 153   Datamatiker
# 154   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
AIDevelopmentToolsDataFrame
# Out:
#              FinishList     Programme  HalfYear  Year AIDevelopmentTools
# 0   2024-03-05 12:23:01  Webudvikling         1  2024   OpenAI (ChatGPT)
# 1   2024-03-08 12:49:29  Webudvikling         1  2024     GitHub Copilot
# 2   2024-03-11 12:28:56   Datamatiker         1  2024     GitHub Copilot
# 3   2024-03-14 13:13:12  Webudvikling         1  2024              Other
# 4   2024-03-14 15:15:06   Datamatiker         1  2024     GitHub Copilot
# ..                  ...           ...       ...   ...                ...
# 166 2025-10-24 11:01:06   Datamatiker         2  2025     GitHub Copilot
# 167 2025-10-24 11:01:06   Datamatiker         2  2025              Other
# 168 2025-10-24 11:29:51   Datamatiker         2  2025     GitHub Copilot
# 169 2025-10-24 11:29:51   Datamatiker         2  2025              Other
# 170 2025-10-24 12:10:55   Datamatiker         2  2025              Other
#
# [171 rows x 5 columns]

# %% [markdown]
# ##Analyse

# %%
# @title
{
    AIDevelopmentToolsDataFrame['AIDevelopmentTools']
    .value_counts()
    .plot(kind='bar',
          title='AI værktøjer anvendt i udviklingsarbejdet i virksomheden',
          xlabel='Værktøjer',
          ylabel='Antal tilkendegivelser')
};

# %% [markdown]
# #AI understøttede aktiviteter i udviklingsarbejdet

# %% [markdown]
# Spm. 11 I tilfælde af at der anvendes AI, angiv hvad det anvendes til ?
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. Kodegenerering
# 2. Dokumentation
# 3. Testing
# 4. Kravspecifikation
# 5. Refactoring
# 6. Debugging
# 7. Code review

# %% [markdown]
# ##Python stuff

# %%
AISupportedDevActSet = {
                 "Kodegenerering",
                 "Dokumentation",
                 "Testing",
                 "Kravspecifikation",
                 "Refactoring",
                 "Debugging",
                 "Code review"
                 }

# %%
AISupportedDevActDataset = dataset[['Finish','AIDevelopmentAppliance','Programme']]

# %%
AISupportedDevActDataFrame,OtherAISupportedDevActList=GetSetAnalysisDataFrame(AISupportedDevActDataset,AISupportedDevActSet,"AIDevelopmentAppliance")

# %%
OtherAISupportedDevActList
# Out:
# ['applikations brug, integreret i applikationer',
#  'Kode assistance',
#  'Suggestions til brugerne',
#  'generering af personaer',
#  'Communication, Tolk',
#  'Sparings partner',
#  'Sparringspartner',
#  'Sparringspartner',
#  'Sparringspartner',
#  'Templates, Visualisering, Commitmessages',
#  'forstå eksisterende kode',
#  'automatesiring, katagoresiring',
#  'Opslag',
#  'ideer til kode',
#  'ideer til kode',
#  'ikke noget specifik ',
#  'Analyse i app.',
#  'i app AI til logistik',
#  'løsningsforslag',
#  'Syntaks Og sparing af kode + systematisk troubleshooting',
#  'Spec-driven Development, Context Engineering',
#  'Beskrivelse af opgaver']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
AISupportedDevActDataset
# Out:
#                  Finish                             AIDevelopmentAppliance  \
# 0   2023-09-15 14:46:54                                                NaN
# 1   2023-09-18 11:31:36                                                NaN
# 2   2023-09-18 13:39:22                                                NaN
# 3   2023-09-18 14:02:34                                                NaN
# 4   2023-09-19 14:10:31                                                NaN
# ..                  ...                                                ...
# 150 2025-10-21 15:22:07  Kodegenerering;Syntaks Og sparing af kode + sy...
# 151 2025-10-21 16:13:41            Kodegenerering;Dokumentation;Debugging;
# 152 2025-10-24 11:01:06  Kodegenerering;Kravspecifikation;Spec-driven D...
# 153 2025-10-24 11:29:51  Kodegenerering;Debugging;Code review;Beskrivel...
# 154 2025-10-24 12:10:55  Kodegenerering;Dokumentation;Testing;Kravspeci...
#
#         Programme
# 0     Datamatiker
# 1     Datamatiker
# 2    Webudvikling
# 3    Webudvikling
# 4     Datamatiker
# ..            ...
# 150   Datamatiker
# 151   Datamatiker
# 152   Datamatiker
# 153   Datamatiker
# 154   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
AISupportedDevActDataFrame
# Out:
#              FinishList     Programme  HalfYear  Year AIDevelopmentAppliance
# 0   2024-03-05 12:23:01  Webudvikling         1  2024                Testing
# 1   2024-03-08 12:49:29  Webudvikling         1  2024            Refactoring
# 2   2024-03-08 12:49:29  Webudvikling         1  2024         Kodegenerering
# 3   2024-03-08 12:49:29  Webudvikling         1  2024              Debugging
# 4   2024-03-08 12:49:29  Webudvikling         1  2024          Dokumentation
# ..                  ...           ...       ...   ...                    ...
# 277 2025-10-24 12:10:55   Datamatiker         2  2025                Testing
# 278 2025-10-24 12:10:55   Datamatiker         2  2025      Kravspecifikation
# 279 2025-10-24 12:10:55   Datamatiker         2  2025            Refactoring
# 280 2025-10-24 12:10:55   Datamatiker         2  2025              Debugging
# 281 2025-10-24 12:10:55   Datamatiker         2  2025            Code review
#
# [282 rows x 5 columns]

# %% [markdown]
# ##Analyse

# %%
# @title
{
    AISupportedDevActDataFrame['AIDevelopmentAppliance']
    .value_counts()
    .plot(kind='bar',
          title='AI understøttede aktiviteter i udviklingsarbejdet i virksomheden',
          xlabel='Værktøjer',
          ylabel='Antal tilkendegivelser')
};

# %% [markdown]
# #Systemudviklingsmetoder

# %% [markdown]
# Spm. 12: Angiv de vigtigste systemudviklingsmetoder der anvendes i virksomheden.
#
#
# Respondenten kunne vælge et eller flere af nedenstående svar samt anføre et vilkårligt svar under "Andet":
# 1. DevOps
# 2. Extreme programming
# 3. Lean
# 4. Prototyping
# 5. Rapid application development (RAD)
# 6. Scrum
# 7. Unified process / Rational Unified Process
# 8. Waterfall
# 9. No method

# %% [markdown]
# ##Python stuff

# %%
SystemDevMethodsSet = {
                 "DevOps",
                 "Extreme programming",
                 "Lean",
                 "Prototyping",
                 "Rapid application development (RAD)",
                 "Scrum",
                 "Unified process / Rational Unified Process",
                 "Waterfall",
                 "No method"
                 }

# %%
SystemDevMethodsDataset = dataset[['Finish','SystemDevMethods','Programme']]

# %%
SystemDevMethodsDataFrame,OtherSystemDevMethodsList=GetSetAnalysisDataFrame(SystemDevMethodsDataset,SystemDevMethodsSet,"SystemDevMethods")

# %%
def GetSystemDevMethodsCounts(method):
  GroupByYear = SystemDevMethodsDataFrame.query(f"SystemDevMethods == \"{method}\"").groupby(['Year'])['SystemDevMethods'].count()
  return GroupByYear.to_list()

# %%
OtherSystemDevMethodsList
# Out:
# ['ShapeUp',
#  'Kanban',
#  'Lidt Scrum',
#  'Daily stand-ups igennem task management system Jira (quick sprints)',
#  'Struktur med morgen og aftenmøder',
#  'uformel agile',
#  'Elementer fra SCRUM ',
#  'scrum light',
#  'lille agile lean med kanban',
#  'Scrum lignende ',
#  'Kanban',
#  'Kanban',
#  'agil system med ro til opgaverne',
#  'En kombination af vandfald og agil, da der bliver brugt sprints til noget udvikling, men hovedsageligt vandfald',
#  'begrænset Scrum, kun 3 udviklere',
#  'en kombination af forkskellig metoder',
#  'Kontallation af valgte emner men ikke rigidt',
#  'Agile, CI/CD',
#  'kanban',
#  'gitops',
#  'Agile',
#  'Corporate Rebels',
#  'Corporate Rebels',
#  'Corporate Rebels',
#  'Corporate Rebels',
#  'meget flad stuktur',
#  'ganske lidt scrum lignende',
#  'Egne retningslinjer',
#  'Agil udvikling',
#  'Agil Udvikling',
#  'togaf',
#  ' arkitekt baseret framework',
#  'CI/CD',
#  'Secure Lifecycle Development Software',
#  'Inddrager relevante værktøjer.',
#  'Kun et lille udpluk af scrum',
#  'kanban',
#  'en kombination efter behov',
#  'Safe',
#  'Ugentlige møder til drift & vedligehold',
#  'Agile-light. Ugentlig "standup", backlog. Ingen pm.',
#  'githup actions',
#  'Tilpasset scrum med XP elementer']

# %% [markdown]
# ##Basis datasæt

# %%
# @title
SystemDevMethodsDataset
# Out:
#                  Finish                                   SystemDevMethods  \
# 0   2023-09-15 14:46:54                                             Scrum;
# 1   2023-09-18 11:31:36  DevOps;Extreme programming;Scrum;Prototyping;S...
# 2   2023-09-18 13:39:22                                     DevOps;Kanban;
# 3   2023-09-18 14:02:34             Extreme programming;Scrum;Prototyping;
# 4   2023-09-19 14:10:31             Extreme programming;Prototyping;Scrum;
# ..                  ...                                                ...
# 150 2025-10-21 15:22:07           Ugentlige møder til drift & vedligehold;
# 151 2025-10-21 16:13:41      DevOps;Extreme programming;Prototyping;Scrum;
# 152 2025-10-24 11:01:06  DevOps;Agile-light. Ugentlig "standup", backlo...
# 153 2025-10-24 11:29:51                              Scrum;githup actions;
# 154 2025-10-24 12:10:55            Scrum;Tilpasset scrum med XP elementer;
#
#         Programme
# 0     Datamatiker
# 1     Datamatiker
# 2    Webudvikling
# 3    Webudvikling
# 4     Datamatiker
# ..            ...
# 150   Datamatiker
# 151   Datamatiker
# 152   Datamatiker
# 153   Datamatiker
# 154   Datamatiker
#
# [151 rows x 3 columns]

# %% [markdown]
# ##Analyse datasæt

# %%
# @title
SystemDevMethodsDataFrame
# Out:
#              FinishList    Programme  HalfYear  Year     SystemDevMethods
# 0   2023-09-15 14:46:54  Datamatiker         2  2023                Scrum
# 1   2023-09-18 11:31:36  Datamatiker         2  2023               DevOps
# 2   2023-09-18 11:31:36  Datamatiker         2  2023  Extreme programming
# 3   2023-09-18 11:31:36  Datamatiker         2  2023                Scrum
# 4   2023-09-18 11:31:36  Datamatiker         2  2023          Prototyping
# ..                  ...          ...       ...   ...                  ...
# 270 2025-10-24 11:01:06  Datamatiker         2  2025                Other
# 271 2025-10-24 11:29:51  Datamatiker         2  2025                Scrum
# 272 2025-10-24 11:29:51  Datamatiker         2  2025                Other
# 273 2025-10-24 12:10:55  Datamatiker         2  2025                Scrum
# 274 2025-10-24 12:10:55  Datamatiker         2  2025                Other
#
# [275 rows x 5 columns]

# %% [markdown]
# ##Analyser

# %%
# @title
{
    SystemDevMethodsDataFrame['SystemDevMethods']
    .value_counts()
    .plot(kind='bar',
          title='Systemudviklingsmetoder anvendt i virksomheden',
          xlabel='Metoder',
          ylabel='Antal tilkendegivelser')
};

# %%
# @title
plotdata = pd.DataFrame({
    "Scrum":GetSystemDevMethodsCounts("Scrum"),
    "DevOps":GetSystemDevMethodsCounts("DevOps"),
    "Extreme programming":GetSystemDevMethodsCounts("Extreme programming"),
    "Prototyping":GetSystemDevMethodsCounts("Prototyping"),
    "Waterfall":GetSystemDevMethodsCounts("Waterfall")

    },
    index=["2023", "2024", "2025"]
)
plotdata.plot(kind="bar", xlabel="År", ylabel="Antal tilkendegivelser",title="Mest udbredte system udviklingmetoder" );

# %%
# @title
stacked_data = plotdata.apply(lambda x: x*100/sum(x), axis=1)
stacked_data.plot(kind="bar", stacked=True,  xlabel="År", ylabel="Antal tilkendegivelser (%)",title="Mest udbredte system udviklingmetoder (relativt)");

# %% [markdown]
# #Applikationssikkerhed

# %% [markdown]
# Spm. 13: I hvor høj grad overvejes IT-sikkerheds praktikker ifm. softwareudvikling, i din virksomhed?
#
#
# 1. Logning af ændringer
# 2. Mulighed for tilbagerulning af ændringer
# 3. Sikkerhedshedkrav til applikationen
# 4. Standardiserede udviklingsmiljøer
# 5. Standardiserede testprocedurer
# 6. Beskyttelse af produktionsmiljøet
# 7. Procedure for håndtering af ændrede applikationskrav
#
# Hver af ovennævnte gradueres med en af følgende valgmuligheder:
# *   I høj grad
# *   I nogen grad
# *   Overhovedet ikke
# *   Ved ikke

# %% [markdown]
# ##Python stuff

# %%
AppSecurityDataset = dataset[['Employees','LoggingChanges','OptionForRollBack','AppSecurityRequirements','StandardizedDevEnv', 'StandardizedTestProc','ProtectionProdEnv','ProcedureChangedAppReq']]

# %% [markdown]
# ##Basis datasæt

# %%
# @title
AppSecurityDataset
# Out:
#                      Employees LoggingChanges OptionForRollBack  \
# 0    1. Under 10 medarbejdere             NaN               NaN
# 1        2. 10-49 medarbejdere            NaN               NaN
# 2        2. 10-49 medarbejdere            NaN               NaN
# 3    1. Under 10 medarbejdere             NaN               NaN
# 4    1. Under 10 medarbejdere             NaN               NaN
# ..                         ...            ...               ...
# 150   4. Over 250 medarbejdere   I nogen grad        I høj grad
# 151  1. Under 10 medarbejdere      I høj grad        I høj grad
# 152   4. Over 250 medarbejdere     I høj grad      I nogen grad
# 153     3. 50-249 medarbejdere     I høj grad        I høj grad
# 154   4. Over 250 medarbejdere     I høj grad        I høj grad
#
#     AppSecurityRequirements StandardizedDevEnv StandardizedTestProc  \
# 0                       NaN                NaN                  NaN
# 1                       NaN                NaN                  NaN
# 2                       NaN                NaN                  NaN
# 3                       NaN                NaN                  NaN
# 4                       NaN                NaN                  NaN
# ..                      ...                ...                  ...
# 150              I høj grad         I høj grad           I høj grad
# 151              I høj grad       I nogen grad           I høj grad
# 152              I høj grad       I nogen grad             Ved ikke
# 153              I høj grad         I høj grad           I høj grad
# 154              I høj grad         I høj grad           I høj grad
#
#     ProtectionProdEnv ProcedureChangedAppReq
# 0                 NaN                    NaN
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4                 NaN                    NaN
# ..                ...                    ...
# 150        I høj grad             I høj grad
# 151        I høj grad           I nogen grad
# 152        I høj grad             I høj grad
# 153        I høj grad             I høj grad
# 154        I høj grad             I høj grad
#
# [151 rows x 8 columns]

# %% [markdown]
# ##Analyse

# %% [markdown]
# **Logning af ændringer:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['LoggingChanges'])
# Out:
# LoggingChanges             I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere           16            12                 2
# 2. 10-49 medarbejdere              11             5                 1
# 3. 50-249 medarbejdere             14             1                 0
# 4. Over 250 medarbejdere           21             4                 1
#
# LoggingChanges             Ved ikke
# Employees
# 1. Under 10 medarbejdere          8
# 2. 10-49 medarbejdere             3
# 3. 50-249 medarbejdere            1
# 4. Over 250 medarbejdere          6

# %% [markdown]
# **Mulighed for tilbagerulning af ændringer:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['OptionForRollBack'])
# Out:
# OptionForRollBack          I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere           23            10                 1
# 2. 10-49 medarbejdere              15             3                 0
# 3. 50-249 medarbejdere             14             1                 0
# 4. Over 250 medarbejdere           23             4                 0
#
# OptionForRollBack          Ved ikke
# Employees
# 1. Under 10 medarbejdere          4
# 2. 10-49 medarbejdere             2
# 3. 50-249 medarbejdere            1
# 4. Over 250 medarbejdere          5

# %% [markdown]
# **Sikkerhedshedkrav til applikationen:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['AppSecurityRequirements'])
# Out:
# AppSecurityRequirements    I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere           19            10                 1
# 2. 10-49 medarbejdere              13             5                 0
# 3. 50-249 medarbejdere             13             3                 0
# 4. Over 250 medarbejdere           22             2                 2
#
# AppSecurityRequirements    Ved ikke
# Employees
# 1. Under 10 medarbejdere          8
# 2. 10-49 medarbejdere             2
# 3. 50-249 medarbejdere            0
# 4. Over 250 medarbejdere          6

# %% [markdown]
# **Standardiserede udviklingsmiljøer:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['StandardizedDevEnv'])
# Out:
# StandardizedDevEnv         I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere           11            22                 1
# 2. 10-49 medarbejdere               6             8                 3
# 3. 50-249 medarbejdere              6             8                 1
# 4. Over 250 medarbejdere           20             6                 0
#
# StandardizedDevEnv         Ved ikke
# Employees
# 1. Under 10 medarbejdere          4
# 2. 10-49 medarbejdere             3
# 3. 50-249 medarbejdere            1
# 4. Over 250 medarbejdere          6

# %% [markdown]
# **Standardiserede testprocedurer:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['StandardizedTestProc'])
# Out:
# StandardizedTestProc       I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere           10            16                 9
# 2. 10-49 medarbejdere               8             9                 2
# 3. 50-249 medarbejdere              7             6                 2
# 4. Over 250 medarbejdere           16            12                 1
#
# StandardizedTestProc       Ved ikke
# Employees
# 1. Under 10 medarbejdere          3
# 2. 10-49 medarbejdere             1
# 3. 50-249 medarbejdere            1
# 4. Over 250 medarbejdere          3

# %% [markdown]
# **Beskyttelse af produktionsmiljøet:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['ProtectionProdEnv'])
# Out:
# ProtectionProdEnv          I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere           15            11                 1
# 2. 10-49 medarbejdere              15             1                 0
# 3. 50-249 medarbejdere             12             0                 0
# 4. Over 250 medarbejdere           24             2                 1
#
# ProtectionProdEnv          Ved ikke
# Employees
# 1. Under 10 medarbejdere         11
# 2. 10-49 medarbejdere             3
# 3. 50-249 medarbejdere            4
# 4. Over 250 medarbejdere          5

# %% [markdown]
# **Procedure for håndtering af ændrede applikationskrav:**

# %%
# @title
pd.crosstab(AppSecurityDataset['Employees'],AppSecurityDataset['ProcedureChangedAppReq'])
# Out:
# ProcedureChangedAppReq     I høj grad  I nogen grad  Overhovedet ikke  \
# Employees
# 1. Under 10 medarbejdere            9            15                 3
# 2. 10-49 medarbejdere               7             7                 0
# 3. 50-249 medarbejdere              9             4                 1
# 4. Over 250 medarbejdere           18             5                 2
#
# ProcedureChangedAppReq     Ved ikke
# Employees
# 1. Under 10 medarbejdere         11
# 2. 10-49 medarbejdere             6
# 3. 50-249 medarbejdere            2
# 4. Over 250 medarbejdere          7
